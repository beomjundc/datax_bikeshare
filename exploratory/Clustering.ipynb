# %%
import numpy as np
import pandas as pd

# %%
#Read data & print the head
df = pd.read_csv('fordBike_tripData_201901.csv')
df.head()
# Out:
#    duration_sec                   start_time  start_station_id  \
# 0           226  2019-01-01 00:07:10.576 UTC             245.0
# 1          1767  2019-01-01 00:08:39.659 UTC              16.0
# 2           182  2019-01-01 00:09:56.211 UTC             269.0
# 3           565  2019-01-01 00:11:03.441 UTC             269.0
# 4           710  2019-01-01 00:14:48.398 UTC             163.0
#
#              start_station_name  end_station_id             end_station_name  \
# 0        Downtown Berkeley BART           247.0    Fulton St at Bancroft Way
# 1       Steuart St at Market St           115.0           Jackson Playground
# 2  Telegraph Ave at Carleton St           240.0    Haste St at Telegraph Ave
# 3  Telegraph Ave at Carleton St           243.0  Bancroft Way at College Ave
# 4     Lake Merritt BART Station           159.0         24th St at Market St
#
#     user_type bike_share_for_all_trip
# 0    Customer                      No
# 1    Customer                      No
# 2  Subscriber                     Yes
# 3  Subscriber                     Yes
# 4    Customer                      No

# %%
# Get the one-way route volume for all trips

# Concatenate start and end stations to count how many trips were made with that combination
df["start_station|end_station"] = df["start_station_id"].map(str) +"|" + df["end_station_id"].map(str)    
df["route"] = df["start_station_name"].map(str) +"|" + df["end_station_name"].map(str)
df["route_volume"] = df["start_station|end_station"]

# Get the volume count for each route
route_volume_series = df["start_station|end_station"].value_counts()
route_volume_dict = route_volume_series.to_dict()

# Write the volume number to each row in the DF
df['route_volume'] = df['route_volume'].map(route_volume_dict) 

# Sort DF by route volume
df_volume_sort = df[['start_station|end_station', 'route', 'route_volume', 'duration_sec']]
df_volume_sort = df_volume_sort.sort_values(by='route_volume', ascending=False)
df_volume_sort.head()
# Out:
#        start_station|end_station  \
# 109977                  15.0|6.0
# 124182                  15.0|6.0
# 68163                   15.0|6.0
# 50167                   15.0|6.0
# 67124                   15.0|6.0
#
#                                                     route  route_volume  \
# 109977  San Francisco Ferry Building (Harry Bridges Pl...           453
# 124182  San Francisco Ferry Building (Harry Bridges Pl...           453
# 68163   San Francisco Ferry Building (Harry Bridges Pl...           453
# 50167   San Francisco Ferry Building (Harry Bridges Pl...           453
# 67124   San Francisco Ferry Building (Harry Bridges Pl...           453
#
#         duration_sec
# 109977           361
# 124182           265
# 68163            402
# 50167           1885
# 67124            444

# %%
df_volume_sort["route"][0] # most popular route
# Out:
# 'Downtown Berkeley BART|Fulton St at Bancroft Way'

# %%
# To group common routes in the same cluster, make a column for the reciprical of route volume. 
# We will cluster on the reciprical to promote high volume routes being clustered together.
df_volume_sort['route_volume_reciprical'] = 1/df_volume_sort['route_volume']

df_volume_cluster = df_volume_sort[['route_volume_reciprical', 'duration_sec']]
df_volume_cluster.head()
# Out:
#         route_volume_reciprical  duration_sec
# 109977                 0.002208           361
# 124182                 0.002208           265
# 68163                  0.002208           402
# 50167                  0.002208          1885
# 67124                  0.002208           444

# %% [markdown]
# ## Normalize the Data

# %%
from sklearn import preprocessing

x = df_volume_cluster.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_cluster = pd.DataFrame(x_scaled)
df_cluster.head()
# Out:
#      0         1
# 0  0.0  0.003574
# 1  0.0  0.002430
# 2  0.0  0.004062
# 3  0.0  0.021730
# 4  0.0  0.004563

# %% [markdown]
# ## Testing the clustering stuff below...in progress.

# %%
# Cluster by route_volume_reciprical

from sklearn.cluster import AgglomerativeClustering
# import warnings
# warnings.filterwarnings('ignore')

# Create clustering object
cluster_model = AgglomerativeClustering(n_clusters=10)

array_cluster = df_cluster.as_matrix()

array_cluster

cluster_model.fit(array_cluster)

# print(cluster_model.labels_[0])


# df_volume_cluster['Cluster'] = cluster_model

# test = np.array([[1, 0.5], [2, .75]])

# print(cluster_model.fit_predict(test))

# df_volume_cluster.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-1b502824fd92> in <module>
#      12 array_cluster
#      13
# ---> 14 cluster_model.fit(array_cluster)
#      15
#      16 # print(cluster_model.labels_[0])
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\sklearn\cluster\hierarchical.py in fit(self, X, y)
#     829             memory.cache(tree_builder)(X, connectivity,
#     830                                        n_clusters=n_clusters,
# --> 831                                        **kwargs)
#     832         # Cut the tree
#     833         if compute_full_tree:
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\sklearn\externals\joblib\memory.py in __call__(self, *args, **kwargs)
#     340
#     341     def __call__(self, *args, **kwargs):
# --> 342         return self.func(*args, **kwargs)
#     343
#     344     def call_and_shelve(self, *args, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\sklearn\cluster\hierarchical.py in ward_tree(X, connectivity, n_clusters, return_distance)
#     232                           stacklevel=2)
#     233         X = np.require(X, requirements="W")
# --> 234         out = hierarchy.ward(X)
#     235         children_ = out[:, :2].astype(np.intp)
#     236
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\scipy\cluster\hierarchy.py in ward(y)
#     480
#     481     """
# --> 482     return linkage(y, method='ward', metric='euclidean')
#     483
#     484
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#     706                          'matrix looks suspiciously like an uncondensed '
#     707                          'distance matrix')
# --> 708         y = distance.pdist(y, metric)
#     709     else:
#     710         raise ValueError("`y` must be 1 or 2 dimensional.")
#
# ~\AppData\Local\Continuum\anaconda3\envs\data-x\lib\site-packages\scipy\spatial\distance.py in pdist(X, metric, *args, **kwargs)
#    1875     out = kwargs.pop("out", None)
#    1876     if out is None:
# -> 1877         dm = np.empty((m * (m - 1)) // 2, dtype=np.double)
#    1878     else:
#    1879         if out.shape != (m * (m - 1) // 2,):
#
# MemoryError:
